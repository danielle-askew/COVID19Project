# %% [markdown]
# # Connect to PGAdmin database

# %%
# Use these commands to install libraries to mlenv environment
#pip install sqlalchemy
#pip install psycopg2
# psycopg2 is needed to interact with postgres

# %%
# Link to guide used to create this page
# https://medium.com/analytics-vidhya/postgresql-integration-with-jupyter-notebook-deb97579a38d

# %%
import pandas as pd
from config import db_password

# %%
# Use create_engine function from sqlalchemy
from sqlalchemy import create_engine

# %%
# connect sqlalchemy to the database
# Format is below
# engine = create_engine('dialect+driver://username:password@host:port/database')
engine = create_engine(f'postgresql://root:{db_password}@mypostgresdb.c0f5nshtds0b.us-east-1.rds.amazonaws.com/test_db')

# %%
# read in tables as a pandas DataFrame
# use pd.read_sql('SQL query', engine)

test_df = pd.read_sql('SELECT * FROM covidspike', engine)

test_df.head()

# %%
# Read in another table

test_df2 = pd.read_sql('SELECT * FROM vaccinedata', engine)

test_df2
# Out:
#                date   fips  mmwr_week       recip_county recip_state  \
# 0        2021-11-13  13083         45        Dade County          GA
# 1        2021-11-13  12043         45      Glades County          FL
# 2        2021-11-13  12045         45        Gulf County          FL
# 3        2021-11-13  40069         45    Johnston County          OK
# 4        2021-11-13  48109         45   Culberson County          TX
# ...             ...    ...        ...                ...         ...
# 1033936  2021-11-13  53043         45     Lincoln County          WA
# 1033937  2021-11-13  53045         45       Mason County          WA
# 1033938  2021-11-13  18067         45      Howard County          IN
# 1033939  2021-11-13  18069         45  Huntington County          IN
# 1033940  2021-11-13  48435         45      Sutton County          TX
#
#          completeness_pct  administered_dose1_recip  \
# 0                    58.2                    4372.0
# ...

# %%
test_df3 = pd.read_sql('SELECT * FROM covaccinespike', engine)

test_df3
# Out:
#           date  fips  mmwr_week       recip_county recip_state  \
# 0   2021-11-08  8103         45  Rio Blanco County          CO
# 1   2021-11-08  8007         45   Archuleta County          CO
# 2   2021-11-08  8029         45       Delta County          CO
# 3   2021-11-08  8121         45  Washington County          CO
# 4   2021-11-08  8047         45      Gilpin County          CO
# ..         ...   ...        ...                ...         ...
# 60  2021-11-08  8083         45   Montezuma County          CO
# 61  2021-11-08  8013         45     Boulder County          CO
# 62  2021-11-08  8055         45    Huerfano County          CO
# 63  2021-11-08  8069         45     Larimer County          CO
# 64  2021-11-08  8039         45      Elbert County          CO
#
#     completeness_pct  administered_dose1_recip  administered_dose1_pop_pct  \
# 0               97.3                      2513                        39.7
# ...
